# %%
import os

# %%
directory = os.path.join(os.getcwd(),"glom_tiles")
temp=0
t=0
for count, filename in enumerate(os.listdir(directory)):
    print(filename)
    if count%2==0:
        os.rename(os.path.join(directory,filename), str(t).zfill(5)+filename[-4:])
    else:
        os.rename(os.path.join(directory,filename), str(t).zfill(5)+filename[-4:])
        t+=1
# Out:
# 10.jpg
# 10.xml
# 100.jpg
# 100.xml
# 101.jpg
# 101.xml
# 102.jpg
# 102.xml
# 103.jpg
# 103.xml
# 104.jpg
# 104.xml
# 105.jpg
# 105.xml
# 106.jpg
# 106.xml
# 107.jpg
# 107.xml
# 11.jpg
# 11.xml
# 113.jpg
# 113.xml
# 114.jpg
# 114.xml
# 115.jpg
# 115.xml
# 116.jpg
# 116.xml
# 117.jpg
# 117.xml
# 118.jpg
# 118.xml
# 119.jpg
# 119.xml
# 120.jpg
# 120.xml
# 121.jpg
# 121.xml
# 122.jpg
# 122.xml
# 128.jpg
# 128.xml
# 129.jpg
# 129.xml
# 130.jpg
# 130.xml
# 131.jpg
# 131.xml
# 132.jpg
# 132.xml
# 133.jpg
# 133.xml
# 134.jpg
# 134.xml
# 143.jpg
# 143.xml
# 144.jpg
# 144.xml
# 145.jpg
# 145.xml
# 146.jpg
# 146.xml
# 147.jpg
# 147.xml
# 148.jpg
# 148.xml
# 149.jpg
# 149.xml
# 15.jpg
# 15.xml
# 158.jpg
# 158.xml
# 159.jpg
# 159.xml
# 16.jpg
# 16.xml
# 160.jpg
# 160.xml
# 161.jpg
# 161.xml
# 162.jpg
# 162.xml
# 163.jpg
# 163.xml
# 164.jpg
# 164.xml
# 17.jpg
# 17.xml
# 18.jpg
# 18.xml
# 19.jpg
# 19.xml
# 20.jpg
# 20.xml
# 21.jpg
# 21.xml
# 22.jpg
# 22.xml
# 23.jpg
# 23.xml
# 24.jpg
# 24.xml
# ...
