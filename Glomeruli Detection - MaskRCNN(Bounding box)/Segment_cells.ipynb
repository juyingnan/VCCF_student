# %%
# Load required libraries

import numpy as np
import pandas as pd
import skimage.io as sk
import cv2
import matplotlib.pyplot as plt
import os

# %%
cell = cv2.imread('./cell_image/test.png')
cell = cv2.cvtColor(cell, cv2.COLOR_BGR2RGB)
plt.imshow(cell)

# %%
print("Cell Shape:",cell.shape)
# Out:
# Cell Shape: (2361, 3600, 3)

# %%
# Cropping

#a1 = round(cell.shape[0]/2)
#a2 = cell.shape[0]
#b1 = cell.shape[1]/2
#b2 = cell.shape[1]

#small_cell = cell[a1:a2,int(b1):b2,:]
#small_cell = cv2.cvtColor(small_cell, cv2.COLOR_BGR2RGB)
#cv2.imwrite("./cell_image/small_test.png",small_cell)
#plt.imshow(small_cell)

# %%
# Resizing

cell_resize3 = cv2.resize(cell, (int(cell.shape[1]*3), int(cell.shape[0]*3)))
plt.imshow(cell_resize3)
cell_resize3 = cv2.cvtColor(cell_resize3, cv2.COLOR_BGR2RGB)
cv2.imwrite("./cell_image/test3.png",cell_resize3)
# Out:
# True

# %%
# Create tiles

a = 0
for i in range(0,cell_resize3.shape[0],600):
    for j in range(0,cell_resize3.shape[1],600):
        tile = cell_resize3[i:i+1080,j:j+1920,:]
        if i+1080 <= cell_resize3.shape[0] and j+1920 <= cell_resize3.shape[1]:
            cv2.imwrite("./glom_tiles/"+str(a)+".jpg",tile)
            a += 1
